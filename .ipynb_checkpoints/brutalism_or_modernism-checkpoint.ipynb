# %%
# install dependencies
pip install -Uqq fastai; pip install -Uqq duckduckgo_search; pip install -Uqq fastbook;

# %%
from fastbook import *
from fastai.vision.widgets import *
from duckduckgo_search import DDGS
from fastcore.all import *

def search_images(term, max_image=80):
    print(f"Searching for '{term}'")
    return L(DDGS().images(term, max_results=max_image)).itemgot('image')

# %%
# images = search_images_ddg('brutalism building')
# ims = images.attrgot('contentUrl')
# len(ims)
# Out:
# 200

# %%
architecture_styles = ['brutalism', 'modernism']

image_urls = {
    'brutalism': 'https://scontent.fsof8-1.fna.fbcdn.net/v/t39.30808-6/348926828_199702382963480_5292274693759943130_n.jpg?stp=cp6_dst-jpg&_nc_cat=111&ccb=1-7&_nc_sid=173fa1&_nc_ohc=0TMBwpZS7DcAX954E_3&_nc_ht=scontent.fsof8-1.fna&oh=00_AfD_VwBdTT4pI6MPzVQxxAbuZgUn9zrm22dxuEwhwovayQ&oe=65E8EE8C',
    'modernism': 'https://media.architecturaldigest.com/photos/579a15e3568683bf3261f40c/master/w_960,c_limit/examples-iconic-modern-architecture-have-serious-flaws-01.jpg'
}

destinations = {
    'brutalism': 'images/brutalism.jpg',
    'modernism': 'images/modernism.jpg'
}

# %%
for url in image_urls:
    download_url(image_urls[url], destinations[url])
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='73728' class='' max='71212' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       103.53% [73728/71212 00:00&lt;00:00]
#     </div>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='417792' class='' max='413744' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.98% [417792/413744 00:00&lt;00:00]
#     </div>

# %%
path = Path('architecture_styles')
from time import sleep

for i in architecture_styles:
    dest = (path/i)
    dest.mkdir(exist_ok=True, parents=True)
    download_images(dest, urls=search_images(f'{i} building'))
    sleep(10)
    resize_images(path/i, max_size=400, dest=path/i)
# Out:
# Searching for 'brutalism building'
# Searching for 'modernism building'

# %%
# remove images that cannot be opened
failed = verify_images(get_image_files(path))
failed.map(Path.unlink)
len(failed)
# Out:
# 8

# %%
# how many images were downloaded
image_files = get_image_files(path)
len(image_files)
# Out:
# 201

# %%
buildings = DataBlock(
    blocks = (ImageBlock, CategoryBlock),
    get_items = get_image_files,
    splitter = RandomSplitter(valid_pct=0.2, seed=42),
    get_y = parent_label,
    item_tfms=Resize(128, ResizeMethod.Squish)
)

# %%
dls = buildings.dataloaders(path)
dls.valid.show_batch(max_n=6, nrows=2)

# %%
learn = vision_learner(dls, resnet18, metrics=error_rate)
learn.fine_tune(4)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.077211</td>
#       <td>0.767120</td>
#       <td>0.250000</td>
#       <td>00:04</td>
#     </tr>
#   </tbody>
# </table>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.602172</td>
#       <td>0.522229</td>
#       <td>0.250000</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.511707</td>
#       <td>0.339552</td>
#       <td>0.225000</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.380394</td>
#       <td>0.272148</td>
#       <td>0.175000</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.302420</td>
#       <td>0.220159</td>
#       <td>0.125000</td>
#       <td>00:06</td>
#     </tr>
#   </tbody>
# </table>

# %%
brutalism = destinations['brutalism']
modernism = destinations['modernism']
image = brutalism

architecture_style,_,probs = learn.predict(PILImage.create(image))
print(f'This is: {architecture_style}')
Image.open(image).to_thumb(256)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# This is: brutalism
# <PIL.Image.Image image mode=RGB size=256x192>
